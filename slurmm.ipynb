# %%
from simple_slurm import Slurm
import datetime

# %%
schedule = [1, 1000, 2000, 3000, 4000, 5000, 6000, 7000, 8000, 9000, 10000, 11000, 12000, 13000, 14000, 15000, 16000, 17000, 18000, 19000, 20000, 21000, 22000, 23000, 24000, 
            25000, 26000, 27000, 28000, 29000, 30000, 31000, 32000, 33000, 34000, 35000, 36000, 37000, 38000, 39000, 40000, 41000, 42000, 43000, 44000, 45000, 46000, 47000, 
            48000, 49000, 50000, 51000, 52000, 53000, 54000, 55000, 56000, 57000, 58000, 59000, 60000, 61000, 62000, 63000, 64000, 65000, 66000, 67000, 68000, 69000, 70000, 
            71000, 72000, 73000, 74000, 75000, 76000, 77000, 78000, 79000, 80000, 81000, 82000, 83000, 84000, 85000, 86000, 87000, 88000, 89000, 90000, 91000, 92000, 93000, 
            94000, 95000, 96000, 97000, 98000, 99000, 100000, 101000, 102000, 103000, 104000, 105000, 106000, 107000, 108000, 109000, 110000, 111000, 112000, 113000, 114000, 
            115000, 116000, 117000, 118000, 118577]

# %%
for i in range(len(schedule) - 1):
    slurm = Slurm(job_name = f"HDGrdey",
              partition = 'l40-gpu',
              gres = 'gpu:1',
              qos = 'gpu_access', 
              mem = "16g",
              time=datetime.timedelta(days=5, hours=0, minutes=0, seconds=0), 
              cpus_per_task=4, 
              output = "/work/users/r/d/rdey/ml_implicit_solvent/slurm_output/%j.out"
              )
    '''
    command = "python -u /work/users/r/d/rdey/ml_implicit_solvent/bigbind_solv/freesolv.py"
    slurm.sbatch(f"source ~/.bashrc && module load cuda && mamba activate solv && {command}")
    '''
    command = f"python /work/users/r/d/rdey/ml_implicit_solvent/bigbind_solv/create_dataset.py simulate {schedule[i]} {schedule[i + 1]}"
    print(command)
    slurm.sbatch(f"source ~/.bashrc && module load cuda && mamba activate solv && {command}")
# Out:
# python /work/users/r/d/rdey/ml_implicit_solvent/bigbind_solv/create_dataset.py simulate 1 1000
# Submitted batch job 51271762
#
# python /work/users/r/d/rdey/ml_implicit_solvent/bigbind_solv/create_dataset.py simulate 1000 2000
# Submitted batch job 51271763
#
# python /work/users/r/d/rdey/ml_implicit_solvent/bigbind_solv/create_dataset.py simulate 2000 3000
# Submitted batch job 51271764
#
# python /work/users/r/d/rdey/ml_implicit_solvent/bigbind_solv/create_dataset.py simulate 3000 4000
# Submitted batch job 51271765
#
# python /work/users/r/d/rdey/ml_implicit_solvent/bigbind_solv/create_dataset.py simulate 4000 5000
# Submitted batch job 51271766
#
# python /work/users/r/d/rdey/ml_implicit_solvent/bigbind_solv/create_dataset.py simulate 5000 6000
# Submitted batch job 51271767
#
# python /work/users/r/d/rdey/ml_implicit_solvent/bigbind_solv/create_dataset.py simulate 6000 7000
# Submitted batch job 51271768
#
# python /work/users/r/d/rdey/ml_implicit_solvent/bigbind_solv/create_dataset.py simulate 7000 8000
# Submitted batch job 51271769
#
# python /work/users/r/d/rdey/ml_implicit_solvent/bigbind_solv/create_dataset.py simulate 8000 9000
# Submitted batch job 51271770
#
# python /work/users/r/d/rdey/ml_implicit_solvent/bigbind_solv/create_dataset.py simulate 9000 10000
# Submitted batch job 51271771
#
# python /work/users/r/d/rdey/ml_implicit_solvent/bigbind_solv/create_dataset.py simulate 10000 11000
# Submitted batch job 51271772
#
# python /work/users/r/d/rdey/ml_implicit_solvent/bigbind_solv/create_dataset.py simulate 11000 12000
# Submitted batch job 51271773
#
# python /work/users/r/d/rdey/ml_implicit_solvent/bigbind_solv/create_dataset.py simulate 12000 13000
# Submitted batch job 51271774
#
# python /work/users/r/d/rdey/ml_implicit_solvent/bigbind_solv/create_dataset.py simulate 13000 14000
# Submitted batch job 51271775
#
# python /work/users/r/d/rdey/ml_implicit_solvent/bigbind_solv/create_dataset.py simulate 14000 15000
# Submitted batch job 51271776
#
# python /work/users/r/d/rdey/ml_implicit_solvent/bigbind_solv/create_dataset.py simulate 15000 16000
# Submitted batch job 51271777
#
# python /work/users/r/d/rdey/ml_implicit_solvent/bigbind_solv/create_dataset.py simulate 16000 17000
# Submitted batch job 51271778
#
# python /work/users/r/d/rdey/ml_implicit_solvent/bigbind_solv/create_dataset.py simulate 17000 18000
# Submitted batch job 51271779
#
# python /work/users/r/d/rdey/ml_implicit_solvent/bigbind_solv/create_dataset.py simulate 18000 19000
# Submitted batch job 51271780
#
# python /work/users/r/d/rdey/ml_implicit_solvent/bigbind_solv/create_dataset.py simulate 19000 20000
# Submitted batch job 51271781
#
# python /work/users/r/d/rdey/ml_implicit_solvent/bigbind_solv/create_dataset.py simulate 20000 21000
# Submitted batch job 51271782
#
# python /work/users/r/d/rdey/ml_implicit_solvent/bigbind_solv/create_dataset.py simulate 21000 22000
# Submitted batch job 51271783
#
# python /work/users/r/d/rdey/ml_implicit_solvent/bigbind_solv/create_dataset.py simulate 22000 23000
# Submitted batch job 51271784
#
# python /work/users/r/d/rdey/ml_implicit_solvent/bigbind_solv/create_dataset.py simulate 23000 24000
# Submitted batch job 51271785
#
# python /work/users/r/d/rdey/ml_implicit_solvent/bigbind_solv/create_dataset.py simulate 24000 25000
# Submitted batch job 51271786
#
# python /work/users/r/d/rdey/ml_implicit_solvent/bigbind_solv/create_dataset.py simulate 25000 26000
# Submitted batch job 51271787
#
# python /work/users/r/d/rdey/ml_implicit_solvent/bigbind_solv/create_dataset.py simulate 26000 27000
# Submitted batch job 51271788
#
# python /work/users/r/d/rdey/ml_implicit_solvent/bigbind_solv/create_dataset.py simulate 27000 28000
# Submitted batch job 51271789
#
# python /work/users/r/d/rdey/ml_implicit_solvent/bigbind_solv/create_dataset.py simulate 28000 29000
# Submitted batch job 51271790
#
# python /work/users/r/d/rdey/ml_implicit_solvent/bigbind_solv/create_dataset.py simulate 29000 30000
# Submitted batch job 51271791
#
# python /work/users/r/d/rdey/ml_implicit_solvent/bigbind_solv/create_dataset.py simulate 30000 31000
# Submitted batch job 51271792
#
# python /work/users/r/d/rdey/ml_implicit_solvent/bigbind_solv/create_dataset.py simulate 31000 32000
# Submitted batch job 51271793
#
# python /work/users/r/d/rdey/ml_implicit_solvent/bigbind_solv/create_dataset.py simulate 32000 33000
# Submitted batch job 51271794
#
# python /work/users/r/d/rdey/ml_implicit_solvent/bigbind_solv/create_dataset.py simulate 33000 34000
# Submitted batch job 51271795
#
# python /work/users/r/d/rdey/ml_implicit_solvent/bigbind_solv/create_dataset.py simulate 34000 35000
# Submitted batch job 51271796
#
# python /work/users/r/d/rdey/ml_implicit_solvent/bigbind_solv/create_dataset.py simulate 35000 36000
# Submitted batch job 51271797
#
# python /work/users/r/d/rdey/ml_implicit_solvent/bigbind_solv/create_dataset.py simulate 36000 37000
# Submitted batch job 51271798
#
# python /work/users/r/d/rdey/ml_implicit_solvent/bigbind_solv/create_dataset.py simulate 37000 38000
# Submitted batch job 51271799
#
# python /work/users/r/d/rdey/ml_implicit_solvent/bigbind_solv/create_dataset.py simulate 38000 39000
# Submitted batch job 51271800
#
# python /work/users/r/d/rdey/ml_implicit_solvent/bigbind_solv/create_dataset.py simulate 39000 40000
# Submitted batch job 51271801
#
# python /work/users/r/d/rdey/ml_implicit_solvent/bigbind_solv/create_dataset.py simulate 40000 41000
# Submitted batch job 51271802
#
# python /work/users/r/d/rdey/ml_implicit_solvent/bigbind_solv/create_dataset.py simulate 41000 42000
# Submitted batch job 51271803
#
# python /work/users/r/d/rdey/ml_implicit_solvent/bigbind_solv/create_dataset.py simulate 42000 43000
# Submitted batch job 51271804
#
# python /work/users/r/d/rdey/ml_implicit_solvent/bigbind_solv/create_dataset.py simulate 43000 44000
# Submitted batch job 51271805
#
# python /work/users/r/d/rdey/ml_implicit_solvent/bigbind_solv/create_dataset.py simulate 44000 45000
# Submitted batch job 51271806
#
# python /work/users/r/d/rdey/ml_implicit_solvent/bigbind_solv/create_dataset.py simulate 45000 46000
# Submitted batch job 51271807
#
# python /work/users/r/d/rdey/ml_implicit_solvent/bigbind_solv/create_dataset.py simulate 46000 47000
# Submitted batch job 51271808
#
# python /work/users/r/d/rdey/ml_implicit_solvent/bigbind_solv/create_dataset.py simulate 47000 48000
# Submitted batch job 51271809
#
# python /work/users/r/d/rdey/ml_implicit_solvent/bigbind_solv/create_dataset.py simulate 48000 49000
# Submitted batch job 51271810
#
# python /work/users/r/d/rdey/ml_implicit_solvent/bigbind_solv/create_dataset.py simulate 49000 50000
# Submitted batch job 51271811
#
# python /work/users/r/d/rdey/ml_implicit_solvent/bigbind_solv/create_dataset.py simulate 50000 51000
# Submitted batch job 51271812
#
# python /work/users/r/d/rdey/ml_implicit_solvent/bigbind_solv/create_dataset.py simulate 51000 52000
# Submitted batch job 51271813
#
# python /work/users/r/d/rdey/ml_implicit_solvent/bigbind_solv/create_dataset.py simulate 52000 53000
# Submitted batch job 51271814
#
# python /work/users/r/d/rdey/ml_implicit_solvent/bigbind_solv/create_dataset.py simulate 53000 54000
# Submitted batch job 51271815
#
# python /work/users/r/d/rdey/ml_implicit_solvent/bigbind_solv/create_dataset.py simulate 54000 55000
# Submitted batch job 51271816
#
# python /work/users/r/d/rdey/ml_implicit_solvent/bigbind_solv/create_dataset.py simulate 55000 56000
# Submitted batch job 51271817
#
# python /work/users/r/d/rdey/ml_implicit_solvent/bigbind_solv/create_dataset.py simulate 56000 57000
# Submitted batch job 51271818
#
# python /work/users/r/d/rdey/ml_implicit_solvent/bigbind_solv/create_dataset.py simulate 57000 58000
# Submitted batch job 51271819
#
# python /work/users/r/d/rdey/ml_implicit_solvent/bigbind_solv/create_dataset.py simulate 58000 59000
# Submitted batch job 51271820
#
# python /work/users/r/d/rdey/ml_implicit_solvent/bigbind_solv/create_dataset.py simulate 59000 60000
# Submitted batch job 51271821
#
# python /work/users/r/d/rdey/ml_implicit_solvent/bigbind_solv/create_dataset.py simulate 60000 61000
# Submitted batch job 51271822
#
# python /work/users/r/d/rdey/ml_implicit_solvent/bigbind_solv/create_dataset.py simulate 61000 62000
# Submitted batch job 51271823
#
# python /work/users/r/d/rdey/ml_implicit_solvent/bigbind_solv/create_dataset.py simulate 62000 63000
# Submitted batch job 51271824
#
# python /work/users/r/d/rdey/ml_implicit_solvent/bigbind_solv/create_dataset.py simulate 63000 64000
# Submitted batch job 51271825
#
# python /work/users/r/d/rdey/ml_implicit_solvent/bigbind_solv/create_dataset.py simulate 64000 65000
# Submitted batch job 51271826
#
# python /work/users/r/d/rdey/ml_implicit_solvent/bigbind_solv/create_dataset.py simulate 65000 66000
# Submitted batch job 51271827
#
# python /work/users/r/d/rdey/ml_implicit_solvent/bigbind_solv/create_dataset.py simulate 66000 67000
# Submitted batch job 51271828
#
# python /work/users/r/d/rdey/ml_implicit_solvent/bigbind_solv/create_dataset.py simulate 67000 68000
# Submitted batch job 51271829
#
# python /work/users/r/d/rdey/ml_implicit_solvent/bigbind_solv/create_dataset.py simulate 68000 69000
# Submitted batch job 51271830
#
# python /work/users/r/d/rdey/ml_implicit_solvent/bigbind_solv/create_dataset.py simulate 69000 70000
# Submitted batch job 51271831
#
# python /work/users/r/d/rdey/ml_implicit_solvent/bigbind_solv/create_dataset.py simulate 70000 71000
# Submitted batch job 51271832
#
# python /work/users/r/d/rdey/ml_implicit_solvent/bigbind_solv/create_dataset.py simulate 71000 72000
# Submitted batch job 51271833
#
# python /work/users/r/d/rdey/ml_implicit_solvent/bigbind_solv/create_dataset.py simulate 72000 73000
# Submitted batch job 51271834
#
# python /work/users/r/d/rdey/ml_implicit_solvent/bigbind_solv/create_dataset.py simulate 73000 74000
# Submitted batch job 51271835
#
# python /work/users/r/d/rdey/ml_implicit_solvent/bigbind_solv/create_dataset.py simulate 74000 75000
# Submitted batch job 51271836
#
# python /work/users/r/d/rdey/ml_implicit_solvent/bigbind_solv/create_dataset.py simulate 75000 76000
# Submitted batch job 51271837
#
# python /work/users/r/d/rdey/ml_implicit_solvent/bigbind_solv/create_dataset.py simulate 76000 77000
# Submitted batch job 51271838
#
# python /work/users/r/d/rdey/ml_implicit_solvent/bigbind_solv/create_dataset.py simulate 77000 78000
# Submitted batch job 51271839
#
# python /work/users/r/d/rdey/ml_implicit_solvent/bigbind_solv/create_dataset.py simulate 78000 79000
# Submitted batch job 51271840
#
# python /work/users/r/d/rdey/ml_implicit_solvent/bigbind_solv/create_dataset.py simulate 79000 80000
# Submitted batch job 51271841
#
# python /work/users/r/d/rdey/ml_implicit_solvent/bigbind_solv/create_dataset.py simulate 80000 81000
# Submitted batch job 51271842
#
# python /work/users/r/d/rdey/ml_implicit_solvent/bigbind_solv/create_dataset.py simulate 81000 82000
# Submitted batch job 51271843
#
# python /work/users/r/d/rdey/ml_implicit_solvent/bigbind_solv/create_dataset.py simulate 82000 83000
# Submitted batch job 51271844
#
# python /work/users/r/d/rdey/ml_implicit_solvent/bigbind_solv/create_dataset.py simulate 83000 84000
# Submitted batch job 51271845
#
# python /work/users/r/d/rdey/ml_implicit_solvent/bigbind_solv/create_dataset.py simulate 84000 85000
# Submitted batch job 51271846
#
# python /work/users/r/d/rdey/ml_implicit_solvent/bigbind_solv/create_dataset.py simulate 85000 86000
# Submitted batch job 51271847
#
# python /work/users/r/d/rdey/ml_implicit_solvent/bigbind_solv/create_dataset.py simulate 86000 87000
# Submitted batch job 51271848
#
# python /work/users/r/d/rdey/ml_implicit_solvent/bigbind_solv/create_dataset.py simulate 87000 88000
# Submitted batch job 51271849
#
# python /work/users/r/d/rdey/ml_implicit_solvent/bigbind_solv/create_dataset.py simulate 88000 89000
# Submitted batch job 51271850
#
# python /work/users/r/d/rdey/ml_implicit_solvent/bigbind_solv/create_dataset.py simulate 89000 90000
# Submitted batch job 51271851
#
# python /work/users/r/d/rdey/ml_implicit_solvent/bigbind_solv/create_dataset.py simulate 90000 91000
# Submitted batch job 51271852
#
# python /work/users/r/d/rdey/ml_implicit_solvent/bigbind_solv/create_dataset.py simulate 91000 92000
# Submitted batch job 51271853
#
# python /work/users/r/d/rdey/ml_implicit_solvent/bigbind_solv/create_dataset.py simulate 92000 93000
# Submitted batch job 51271854
#
# python /work/users/r/d/rdey/ml_implicit_solvent/bigbind_solv/create_dataset.py simulate 93000 94000
# Submitted batch job 51271855
#
# python /work/users/r/d/rdey/ml_implicit_solvent/bigbind_solv/create_dataset.py simulate 94000 95000
# Submitted batch job 51271856
#
# python /work/users/r/d/rdey/ml_implicit_solvent/bigbind_solv/create_dataset.py simulate 95000 96000
# Submitted batch job 51271857
#
# python /work/users/r/d/rdey/ml_implicit_solvent/bigbind_solv/create_dataset.py simulate 96000 97000
# Submitted batch job 51271858
#
# python /work/users/r/d/rdey/ml_implicit_solvent/bigbind_solv/create_dataset.py simulate 97000 98000
# Submitted batch job 51271859
#
# python /work/users/r/d/rdey/ml_implicit_solvent/bigbind_solv/create_dataset.py simulate 98000 99000
# Submitted batch job 51271860
#
# python /work/users/r/d/rdey/ml_implicit_solvent/bigbind_solv/create_dataset.py simulate 99000 100000
# Submitted batch job 51271861
#
# python /work/users/r/d/rdey/ml_implicit_solvent/bigbind_solv/create_dataset.py simulate 100000 101000
# Submitted batch job 51271862
#
# python /work/users/r/d/rdey/ml_implicit_solvent/bigbind_solv/create_dataset.py simulate 101000 102000
# Submitted batch job 51271863
#
# python /work/users/r/d/rdey/ml_implicit_solvent/bigbind_solv/create_dataset.py simulate 102000 103000
# Submitted batch job 51271864
#
# python /work/users/r/d/rdey/ml_implicit_solvent/bigbind_solv/create_dataset.py simulate 103000 104000
# Submitted batch job 51271865
#
# python /work/users/r/d/rdey/ml_implicit_solvent/bigbind_solv/create_dataset.py simulate 104000 105000
# Submitted batch job 51271866
#
# python /work/users/r/d/rdey/ml_implicit_solvent/bigbind_solv/create_dataset.py simulate 105000 106000
# Submitted batch job 51271867
#
# python /work/users/r/d/rdey/ml_implicit_solvent/bigbind_solv/create_dataset.py simulate 106000 107000
# Submitted batch job 51271868
#
# python /work/users/r/d/rdey/ml_implicit_solvent/bigbind_solv/create_dataset.py simulate 107000 108000
# Submitted batch job 51271869
#
# python /work/users/r/d/rdey/ml_implicit_solvent/bigbind_solv/create_dataset.py simulate 108000 109000
# Submitted batch job 51271870
#
# python /work/users/r/d/rdey/ml_implicit_solvent/bigbind_solv/create_dataset.py simulate 109000 110000
# Submitted batch job 51271871
#
# python /work/users/r/d/rdey/ml_implicit_solvent/bigbind_solv/create_dataset.py simulate 110000 111000
# Submitted batch job 51271872
#
# python /work/users/r/d/rdey/ml_implicit_solvent/bigbind_solv/create_dataset.py simulate 111000 112000
# Submitted batch job 51271873
#
# python /work/users/r/d/rdey/ml_implicit_solvent/bigbind_solv/create_dataset.py simulate 112000 113000
# Submitted batch job 51271874
#
# python /work/users/r/d/rdey/ml_implicit_solvent/bigbind_solv/create_dataset.py simulate 113000 114000
# Submitted batch job 51271875
#
# python /work/users/r/d/rdey/ml_implicit_solvent/bigbind_solv/create_dataset.py simulate 114000 115000
# Submitted batch job 51271876
#
# python /work/users/r/d/rdey/ml_implicit_solvent/bigbind_solv/create_dataset.py simulate 115000 116000
# Submitted batch job 51271877
#
# python /work/users/r/d/rdey/ml_implicit_solvent/bigbind_solv/create_dataset.py simulate 116000 117000
# Submitted batch job 51271878
#
# python /work/users/r/d/rdey/ml_implicit_solvent/bigbind_solv/create_dataset.py simulate 117000 118000
# Submitted batch job 51271879
#
# python /work/users/r/d/rdey/ml_implicit_solvent/bigbind_solv/create_dataset.py simulate 118000 118577
# Submitted batch job 51271880

# %%
slurm = Slurm(job_name = "Collate",
            partition = 'general',
            mem = "16g", 
            time=datetime.timedelta(days=0, hours=8, minutes=0, seconds=4), 
            cpus_per_task=1, 
            output = "/work/users/r/d/rdey/ml_implicit_solvent/slurm_output/%j.out"
            )

command = f'python -u /work/users/r/d/rdey/ml_implicit_solvent/bigbind_solv/create_dataset.py collate'
print(command)

slurm.sbatch(f"source ~/.bashrc && module load cuda && mamba activate solv && {command}")
# Out:
# python -u /work/users/r/d/rdey/ml_implicit_solvent/bigbind_solv/create_dataset.py collate
# Submitted batch job 52659530
# 52659530

# %%
slurm = Slurm(job_name = "Collate",
            partition = 'l40-gpu',
              gres = 'gpu:1',
              qos = 'gpu_access', 
              mem = "16g",
              time=datetime.timedelta(days=3, hours=0, minutes=0, seconds=0), 
              cpus_per_task=1, 
              output = "/work/users/r/d/rdey/ml_implicit_solvent/slurm_output/%j.out"
            )

command = f'python -u /work/users/r/d/rdey/ml_implicit_solvent/bigbind_solv/create_dataset.py collate'
print(command)

slurm.sbatch(f"source ~/.bashrc && module load cuda && mamba activate solv && {command}")
# Out:
# python -u /work/users/r/d/rdey/ml_implicit_solvent/bigbind_solv/create_dataset.py collate
# Submitted batch job 52659531
# 52659531

# %%
import itertools
dps = [1e-4]
lambda_elecs = [1]
com = list(itertools.product(dps, lambda_elecs))
for (dp, lambda_elec) in com:
    slurm = Slurm(job_name = f"Simulation1M",
              partition = 'l40-gpu',
              gres = 'gpu:1',
              qos = 'gpu_access', 
              mem = "16g",
              time=datetime.timedelta(days=1, hours=12, minutes=0, seconds=0), 
              cpus_per_task=4, 
              output = "/work/users/r/d/rdey/ml_implicit_solvent/slurm_output/%j.out"
              )
    command = f"python /work/users/r/d/rdey/ml_implicit_solvent/bigbind_solv/epsilon_calculation.py {dp} {lambda_elec}"
    print(command)
    slurm.sbatch(f"source ~/.bashrc && module load cuda && mamba activate solv && {command}")
# Out:
# python /work/users/r/d/rdey/ml_implicit_solvent/bigbind_solv/epsilon_calculation.py 0.0001 1
# Submitted batch job 54282528

# %%
for i in range(5):
    slurm = Slurm(job_name = f"SimulationGraph",
              partition = 'l40-gpu',
              gres = 'gpu:1',
              qos = 'gpu_access', 
              mem = "16g",
              time=datetime.timedelta(days=1, hours=12, minutes=0, seconds=0), 
              cpus_per_task=4, 
              output = "/work/users/r/d/rdey/ml_implicit_solvent/slurm_output/%j.out"
              )
    command = f"python /work/users/r/d/rdey/ml_implicit_solvent/bigbind_solv/graphical_representation.py {i}"
    print(command)
    slurm.sbatch(f"source ~/.bashrc && module load cuda && mamba activate solv && {command}")
# Out:
# python /work/users/r/d/rdey/ml_implicit_solvent/bigbind_solv/graphical_representation.py 0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 13
#      11 command = f"python /work/users/r/d/rdey/ml_implicit_solvent/bigbind_solv/graphical_representation.py {i}"
#      12 print(command)
# ---> 13 slurm.sbatch(f"source ~/.bashrc && module load cuda && mamba activate solv && {command}")
#
# File ~/anaconda3/envs/GNNProject/lib/python3.9/site-packages/simple_slurm/core.py:165, in Slurm.sbatch(self, convert, verbose, sbatch_cmd, shell, *run_cmd)
#     159 self.add_cmd(*run_cmd)
#     160 cmd = '\n'.join((
#     161     sbatch_cmd + ' << EOF',
#     162     self.script(shell, convert),
#     163     'EOF',
#     164 ))
# --> 165 result = subprocess.run(cmd, shell=True, stdout=subprocess.PIPE)
#     166 success_msg = 'Submitted batch job'
#     167 stdout = result.stdout.decode('utf-8')
#
# File ~/anaconda3/envs/GNNProject/lib/python3.9/subprocess.py:507, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     505 with Popen(*popenargs, **kwargs) as process:
#     506     try:
# --> 507         stdout, stderr = process.communicate(input, timeout=timeout)
#     508     except TimeoutExpired as exc:
#     509         process.kill()
#
# File ~/anaconda3/envs/GNNProject/lib/python3.9/subprocess.py:1121, in Popen.communicate(self, input, timeout)
#    1119     self._stdin_write(input)
#    1120 elif self.stdout:
# -> 1121     stdout = self.stdout.read()
#    1122     self.stdout.close()
#    1123 elif self.stderr:
#
# KeyboardInterrupt:

# %%
slurm = Slurm(job_name = f"SimulationIntegration",
            partition = 'volta-gpu',
            gres = 'gpu:1',
            qos = 'gpu_access', 
            mem = "16g",
            time=datetime.timedelta(days=0, hours=1, minutes=0, seconds=0), 
            cpus_per_task=1, 
            output = "/work/users/r/d/rdey/ml_implicit_solvent/slurm_output/%j.out"
            )
command = f"python /work/users/r/d/rdey/ml_implicit_solvent/bigbind_solv/thermodynamic_derivatives.py"
print(command)
slurm.sbatch(f"source ~/.bashrc && module load cuda && mamba activate solv && {command}")
# Out:
# python /work/users/r/d/rdey/ml_implicit_solvent/bigbind_solv/thermodynamic_derivatives.py
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 12
#      10 command = f"python /work/users/r/d/rdey/ml_implicit_solvent/bigbind_solv/thermodynamic_derivatives.py"
#      11 print(command)
# ---> 12 slurm.sbatch(f"source ~/.bashrc && module load cuda && mamba activate solv && {command}")
#
# File ~/anaconda3/envs/GNNProject/lib/python3.9/site-packages/simple_slurm/core.py:165, in Slurm.sbatch(self, convert, verbose, sbatch_cmd, shell, *run_cmd)
#     159 self.add_cmd(*run_cmd)
#     160 cmd = '\n'.join((
#     161     sbatch_cmd + ' << EOF',
#     162     self.script(shell, convert),
#     163     'EOF',
#     164 ))
# --> 165 result = subprocess.run(cmd, shell=True, stdout=subprocess.PIPE)
#     166 success_msg = 'Submitted batch job'
#     167 stdout = result.stdout.decode('utf-8')
#
# File ~/anaconda3/envs/GNNProject/lib/python3.9/subprocess.py:507, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     505 with Popen(*popenargs, **kwargs) as process:
#     506     try:
# --> 507         stdout, stderr = process.communicate(input, timeout=timeout)
#     508     except TimeoutExpired as exc:
#     509         process.kill()
#
# File ~/anaconda3/envs/GNNProject/lib/python3.9/subprocess.py:1121, in Popen.communicate(self, input, timeout)
#    1119     self._stdin_write(input)
#    1120 elif self.stdout:
# -> 1121     stdout = self.stdout.read()
#    1122     self.stdout.close()
#    1123 elif self.stderr:
#
# KeyboardInterrupt:
# sbatch: error: Batch job submission failed: Unable to contact slurm controller (connect failure)
